# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 📌 Load the dataset
df = pd.read_csv("../data/heart.csv")  # Ensure the correct file path

# %%
# 📌 Display the first 5 rows
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0      1.0      168      0      1.0      2
# 1   53    1   0       140   203    1      0.0      155      1      3.1      0
# 2   70    1   0       145   174    0      1.0      125      1      2.6      0
# 3   61    1   0       148   203    0      1.0      161      0      0.0      2
# 4   62    0   0       138   294    1      1.0      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# 📌 Get dataset overview
df.info()

# 📌 Summary statistics
df.describe()

# 📌 Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1024 non-null   float64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1023 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 112.2 KB
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     1
# thalach     0
# exang       0
# oldpeak     2
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# 📌 Drop missing values if any
df.dropna(inplace=True)

# 📌 Remove duplicate records if any
df.drop_duplicates(inplace=True)

# 📌 Verify data after cleaning
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    float64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(2), int64(12)
# memory usage: 35.4 KB

# %%
# 📌 Drop missing values if any
df.dropna(inplace=True)

# 📌 Remove duplicate records if any
df.drop_duplicates(inplace=True)

# 📌 Verify data after cleaning
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    float64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(2), int64(12)
# memory usage: 35.4 KB

# %%
# Set style
sns.set_style("whitegrid")

# 📌 Plot the age distribution
plt.figure(figsize=(8,5))
sns.histplot(df['age'], bins=20, kde=True, color="blue")
plt.title("Distribution of Patients' Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='target', y='age', data=df, hue='target', palette="coolwarm")
plt.title("Age Distribution by Heart Disease Presence")
plt.xlabel("Heart Disease (0 = No, 1 = Yes)")
plt.ylabel("Age")
plt.legend([],[], frameon=False)  # Hide duplicate legend
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
df.to_csv("../data/cleaned_data.csv", index=False)
print("✅ Cleaned dataset has been saved successfully!")
# Out:
# ✅ Cleaned dataset has been saved successfully!

# %%
# !where python
# Out:
# C:\Users\PCCV\anaconda3\python.exe
# C:\Users\PCCV\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !conda activate heart-disease-env
# Out:
# Traceback (most recent call last):
#   File "C:\Users\PCCV\anaconda3\Scripts\conda-script.py", line 11, in <module>
#     from conda.cli import main
#   File "C:\Users\PCCV\anaconda3\Lib\site-packages\conda\__init__.py", line 28, in <module>
#     from frozendict import frozendict
#   File "C:\Users\PCCV\anaconda3\Lib\site-packages\frozendict\__init__.py", line 16, in <module>
#     class frozendict(collections.Mapping):
#                      ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'collections' has no attribute 'Mapping'

# %%
# !pip install frozendict==1.2
# Out:
# Requirement already satisfied: frozendict==1.2 in c:\users\pccv\anaconda3\lib\site-packages (1.2)

# %%
# !pip install --upgrade experta
# Out:
# Requirement already satisfied: experta in c:\users\pccv\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: frozendict==1.2 in c:\users\pccv\anaconda3\lib\site-packages (from experta) (1.2)
# Requirement already satisfied: schema==0.6.7 in c:\users\pccv\anaconda3\lib\site-packages (from experta) (0.6.7)

# %%
# !pip install --no-deps experta
# Out:
# Requirement already satisfied: experta in c:\users\pccv\anaconda3\lib\site-packages (1.9.4)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
